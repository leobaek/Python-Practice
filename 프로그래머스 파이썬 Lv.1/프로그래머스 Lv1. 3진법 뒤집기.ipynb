# %%
from IPython.display import Image
Image('../image/Lv1. 3진법 뒤집기.PNG',width=450)

# %%
def solution(n):
    answer = ''
    while n > 0:
        answer += str(n%3)
        
        n = n // 3
    
    return int(answer,3)
