# %%
from IPython.display import Image
Image('../image/Lv1. 콜라 문제.PNG',width=450)

# %%
# 빈병 a개를 가져다주면 콜라 b병을 준다. 빈병 n개를 가져다주면 몇병을 받을까?

def solution(a, b, n):
    answer = 0
    coke = 0
    
    while (n>=a) :
        
        answer += (((n // a)*b))
        n = (((n // a)*b)+n%a)
        
        
        
        
    
    return answer

# %%
solution(2,1,20)
# Out:
# 19

# %%
c
# Out:
# 1
