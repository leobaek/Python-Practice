# %%
from IPython.display import Image, display
display(Image('../image/Lv1. 로또 최고 순위와 최저 순위1.PNG',width=450))
display(Image('../image/Lv1. 로또 최고 순위와 최저 순위2.PNG',width=450))

# %%
def solution(lottos, win_nums):
    answer = []
    max_score = 0
    min_score = 0
    
    score = {6:1,5:2,4:3,3:4,2:5,1:6,0:6}
    
#     # 로또번호 순회
#     for i in win_nums : 
        
#         # 내 로또 순회하며 로또번호와 일치하면 result에 일치 횟수 추가
#         for j in lottos : 
            
#             # 조건1 안보이는 숫자가 모두 일치할 때, i가 j와 같을 때
#             if i==j and j==0 : 
                
#                 max_score +=1
                
#                 answer.append(score[max_score])
                
#             # 조건2 안보이는 숫자가 모두 일치하지 않을 때, i가 j와 같을 때
#             elif i==j and j!=0 : 
                
#                 min_score += 1 
                
#                 answer.append(score[min_score])
  
    zero_nums = lottos.count(0)
    
    correct_nums = len(set(lottos) & set(win_nums))
    
    
    best = correct_nums + zero_nums
    
    worst = correct_nums
    
    answer.append(score[best])
    answer.append(score[worst])
    
                    
                
                
                
        
        
    return answer

# %%
a =[44, 1, 0, 0, 31, 25]

# %%
b=[31, 10, 45, 1, 6, 19]

# %%
solution(a,b)
# Out:
# [3, 5]

# %%
a[0]
# Out:
# 0

# %%
a[0] = 1

# %%
a
# Out:
# [1, 3, 4, 5, 1, 0, 0]

# %%
score = {6:1,5:2,4:3,3:4,2:5}

# %%
a.append(score[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18060\1298282053.py in <module>
# ----> 1 a.append(score[0])
#
# KeyError: 0
