# %%
from IPython.display import Image
Image('../image/Lv1. 부족한 금액 계산하기.PNG', width=450)

# %%
def solution(price, money, count):
    answer = 0
    use=0
    for i in range(1,count+1):
        use += price*i
    
    if money-use > 0 :
        return 0
    else:
        answer = abs(money-use)

    return answer
