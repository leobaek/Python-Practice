# %%
from IPython.display import Image
Image('../image/Lv1. 문자열을 정수로 바꾸기.png')

# %%
def solution(s):
    answer = 0
    
    answer = int(s)
    
    
    return answer

# %%
solution('-1111')
# Out:
# -1111
# -1111
