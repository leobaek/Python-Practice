# %%
from IPython.display import Image

Image('../image/Lv1. 제일 작은 수 제거하기.PNG', width=450)

# %%
def solution(arr):
    answer = []
    if len(arr) == 1 :
        return [-1]
        
    arr.remove(min(arr))
    answer = arr
    
    
    return answer
