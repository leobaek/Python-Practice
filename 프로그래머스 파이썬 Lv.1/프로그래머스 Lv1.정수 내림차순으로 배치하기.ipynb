# %%
from IPython.display import Image
Image('../image/Lv1.정수 내림차순으로 배치하기.png')

# %%
def solution(n):
    answer = 0
    x = []
    x = list(str(n))
    x = sorted(x,reverse=True)
    answer = int("".join(x))
    return answer

# %%
solution(118372)
# Out:
# 873211

# %%
list(str(a))
# Out:
# ['1', '1', '8', '3', '7', '2']

# %%
z = 118372
z = list(str(z))
z.sort(reverse=True)
print(z)
# Out:
# ['8', '7', '3', '2', '1', '1']
