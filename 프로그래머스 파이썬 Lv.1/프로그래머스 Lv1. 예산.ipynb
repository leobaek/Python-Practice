# %%
from IPython.display import Image
Image('../image/Lv1. 예산.PNG', width=450)

# %%
def solution(d, budget):
    answer = 0
    d.sort()
    for i in d :
        if budget - i >=0:
            budget -= i
            answer +=1
        else : 
            return answer
        
    return len(d)

# %%
d=[1,3,2,5,4]

# %%
d[0]
# Out:
# 1

# %%
type(d[0])
# Out:
# int
