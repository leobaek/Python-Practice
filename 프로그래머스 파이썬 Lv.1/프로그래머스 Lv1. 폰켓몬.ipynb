# %%
from IPython.display import Image
Image('../image/Lv1. 폰켓몬.PNG',width=450)

# %%
def solution(nums):
    answer = 0
    choose = len(nums)/2
    poketmon = []
    
    for i in range(len(nums)):
        
        for j in range(i+1,len(nums)):
            
            poketmon.append([nums[i],nums[j]])
        
    
    print(poketmon)
                 
            
            
        
    
    
    return answer

# %%
a =[3,1,2,3]

# %%
solution(a)
# Out:
# [[3, 1], [3, 2], [3, 3], [1, 2], [1, 3], [2, 3]]
# 0
