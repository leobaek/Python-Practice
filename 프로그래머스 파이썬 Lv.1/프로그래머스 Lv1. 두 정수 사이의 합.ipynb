# %%
from IPython.display import Image
Image('../image/Lv1. 두 정수 사이의 합.png',width = 350)

# %%
def solution(a, b):
    answer = 0
    start = min(a,b)
    end = max(a,b)
    
    answer = sum(range(start, end+1))
        
        
    return answer

# %%
solution(3,5)
# Out:
# 12

# %%
a,b = map(int, input().split())
# Out:
# 3 5
