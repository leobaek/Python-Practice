# %%
from IPython.display import Image
Image('../image/Lv1. 수박수박수박수박수.PNG', width=450)

# %%
def solution(n):
    answer = ''
    for i in range(1,n+1) :
        if i%2 == 0:
            answer+='박'
        else :
            answer+='수'
        
        
    return answer

# %%
solution(5)
# Out:
# '수박수박수'

# %%
g = ['수','박']

# %%
# Out:
# "['수', '박']"
