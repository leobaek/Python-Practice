# %%
from IPython.display import Image
Image("../image/Lv1. 하샤드 수.png", width=400)

# %%
def solution(x):
    # 자릿수의 합
    sum = 0
    
    for i in str(x) :
        sum += int(i)
    
    if x % sum == 0 :
        answer = True
    else :
        answer = False
    
        
 
    return answer
