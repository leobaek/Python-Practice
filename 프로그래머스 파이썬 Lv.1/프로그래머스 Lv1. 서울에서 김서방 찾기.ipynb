# %%
from IPython.display import Image
Image('../image/Lv1. 서울에서 김서방 찾기.png', width=450)

# %%
def solution(seoul):
    answer = f'김서방은 {seoul.index("Kim")}에 있다'
    
            
        
    return answer

# %%
busan = ["Jane","Kim"]

# %%
busan.index("Kim")
# Out:
# 1
