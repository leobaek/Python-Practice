# %%
from IPython.display import Image as img
img('../image/Lv1. x만큼 간격이 있는 n개의 숫자.png')

# %%
def solution(x, n):
    answer = []
    for i in range(1,n+1) :
        a = x * i
        answer.append(a)
        
    return answer

# %%
solution(2,5)
# Out:
# [2, 4, 6, 8, 10]
