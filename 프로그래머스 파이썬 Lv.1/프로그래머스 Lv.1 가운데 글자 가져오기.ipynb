# %%
from IPython.display import Image
Image('../image/Lv1. 가운데 글자 가져오기.PNG', width=450)

# %%
def solution(s):
    answer = ''
    num=0
    if len(s)%2 !=0:
        
        num = len(s) //2 
        answer = s[num]
    else :
        num = len(s) // 2
        num2 = num-1
        answer =s[num2]+s[num]
    
    return answer
