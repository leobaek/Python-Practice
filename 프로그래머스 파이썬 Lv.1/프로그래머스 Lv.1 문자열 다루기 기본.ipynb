# %%
from IPython.display import Image
Image('../image/Lv1. 문자열 다루기 기본.PNG',width=450)

# %%
def solution(s):
    answer = True
    if (len(s) == 4 or len(s)==6) and s.isdigit() == True:
        return True
    else :
        return False

# %%
solution(a)
# Out:
# True

# %%
a.isdigit
# Out:
# <function str.isdigit()>

# %%
a = "1234"

a.isdigit()
# Out:
# True
