# %%
from IPython.display import Image
Image('../image/Lv1. 모의고사.PNG', width=450)

# %%
def solution(answers):
    result = []
    st1=[1,2,3,4,5]
    st2=[2,1,2,3,2,4,2,5]
    st3=[3,3,1,1,2,2,4,4,5,5]
    
    vs = [0,0,0]
  
    for idx, answer in enumerate(answers) : 
        
        if st1[idx%len(st1)] == answer : 
            vs[0]+= 1
        
        if st2[idx%len(st2)] == answer : 
            vs[1]+= 1
        
        if st3[idx%len(st3)] == answer : 
            vs[2]+= 1
    
    
    
    for idx, answer in enumerate(vs) :
        
        if max(vs) == answer : 
            
            result.append(idx+1)
        
        
        
        
        
        
        
        
    
        
        
    
    return result

# %%
solution(a)
# Out:
# [1]

# %%
a =[1,2,3,4,5]

# %%
sorted(a)
# Out:
# [1, 2, 3, 4]

# %%
1%5
# Out:
# 1
