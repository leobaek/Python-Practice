# %%
from IPython.display import Image
Image('../image/Lv1.약수의 합.png', height=5)

# %%
def solution(n):
    answer = 0
    for i in range(1,n+1) :
        if n%i == 0 :
            answer += i
            
        
    return answer

# %%
solution(16)
# Out:
# 31

# %%
x = input()
# Out:
# 12

# %%
type(x)
# Out:
# str

# %%
for i in range(1,5) :
    print(i,end=" ,")
# Out:
# 1 ,2 ,3 ,4 ,
