# %%
from IPython.display import Image
Image('../image/Lv1. 완주하지 못한 선수.PNG',width=450)

# %%
def solution(participant, completion):
    answer = ''
    
    participant.sort()
    completion.sort()
    
    for a,b in zip(participant,completion) : 
        
        if a != b : 
            
            return a
    
    
    return participant[-1]
