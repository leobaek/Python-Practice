# %%
from IPython.display import Image

Image("../image/Lv1. 음양 더하기.PNG", width=450)

# %%
def solution(absolutes, signs):
    answer = 0
    for num, sign in zip(absolutes, signs):
        if sign == True:
            answer +=num
        else:
            answer -=num
    return answer
