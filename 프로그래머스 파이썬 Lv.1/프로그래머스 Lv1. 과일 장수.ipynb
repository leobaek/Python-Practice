# %%
from IPython.display import Image
Image('../image/Lv1. 과일 장수.PNG',width=450)

# %%
def solution(k, m, score):
    answer = 0
    
    score.sort(reverse=True)
    
    if (len(score) / m ) < 2 : 
        answer = min(score[0:m]) *  m
    else :
        for i in range(len(score)/m) :
            min(score(0:m))
    
    
    
    
    return answer

# %%
k=3
m=4
score=[1, 2, 3, 1, 2, 3, 1]

# %%
solution(k,m,score)
# Out:
# 8

# %%
len(score)
# Out:
# 7

# %%
a[4:-1]
# Out:
# [10, 8, 6, 5, 4]
