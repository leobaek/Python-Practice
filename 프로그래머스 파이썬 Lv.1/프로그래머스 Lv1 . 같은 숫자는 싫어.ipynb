# %%
from IPython.display import Image

Image('../image/Lv1. 같은 숫자는 싫어.PNG',width=450)

# %%
def solution(arr):
    answer = []
    for i in range(len(arr)-1):
        if arr[i] != arr[i+1] :
            answer.append[arr[i]]
            
    answer.append(arr[-1])
    
        
    return answer

# %%
arr=[1,1,3,3,0,1,1]

# %%
arr2= list[set(arr)]

# %%
arr2
# Out:
# list[{0, 1, 3}]

# %%
for i in set(arr) :
    list.append(arr)
