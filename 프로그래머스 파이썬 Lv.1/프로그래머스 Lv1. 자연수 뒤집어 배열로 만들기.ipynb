# %%
from IPython.display import Image
Image('../image/Lv1. 자연수 뒤집어 배열로 만들기.png')

# %%
def solution(n):
    answer = []
    n = str(n)
    for i in n :
        i = int(i)
        answer.append(i)
    answer.reverse()
    return answer

# %%
solution2(12345)
# Out:
# [5, 4, 3, 2, 1]

# %%
answer2.reverse()

# %%
print(answer2)
# Out:
# [3, 5, 4, 8, 1, 2]

# %%
answer2.append(2)
