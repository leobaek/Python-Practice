# %%
from IPython.display import Image
Image('../image/Lv1. 숫자 문자열과 영단어.PNG',width=450)

# %%
def solution(s):
    numbers = {"zero":"0","one":"1", "two":"2","three":"3", "four":"4","five":"5","six":"6","seven":"7","eight":"8","nine":"9"}
    for eng,num in numbers.items() :
        if eng in s :
            s = s.replace(eng,num)
        
    
    
    return int(s)

# %%
numbers = {"zero":0,"one":1, "two":2,"three":3, "four":4,"five":5,"six":6,"seven":7,"eight":8,"nine":9}

# %%
numbers.keys()
# Out:
# dict_keys(['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])

# %%
a = "one4seveneight"

# %%
type(a[3])
# Out:
# str
