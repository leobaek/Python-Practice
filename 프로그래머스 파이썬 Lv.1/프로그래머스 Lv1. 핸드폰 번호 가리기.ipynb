# %%
from IPython.display import Image
Image('../image/Lv1. 핸드폰 번호 가리기.PNG' , width=400)

# %%
number = "01055555555"

# %%
number[-4:]
len(number)
# Out:
# 11

# %%
def solution(phone_number):
    answer = ''
    secret = "*" * (len(phone_number)-4)
    use = phone_number[-4:]
    
    answer = secret+use
    
    return answer
