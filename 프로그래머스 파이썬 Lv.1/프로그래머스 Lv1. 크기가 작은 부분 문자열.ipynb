# %%
from IPython.display import Image
Image('../image/Lv1. 크기가 작은 부분문자열.PNG',width=
     450)

# %%
def solution(t, p):
    answer = []
    result=0
    for i in range(0,len(t)-len(p)+1) :
        answer.append(t[i:i+len(p)])
    for j in answer:
        if j <= p:
            result+=1
        
        
    
    return result
