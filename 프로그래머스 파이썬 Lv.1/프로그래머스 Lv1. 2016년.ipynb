# %%
from IPython.display import Image
Image('../image/Lv1. 2016년.PNG',width=450)

# %%
import datetime
def solution(a, b):
    answer = ''
    day = 0
    save = {0:'MON', 1:"TUE",2:"WED",3:"THU", 4:"FRI",5:"SAT",6:"SUN"}
    dt = datetime.date(2016,a,b)
    day = dt.weekday()
    answer = save[day]
    return answer

# %%
save = {0:'MON', 1:"TUE",2:"WED",3:"THU", 4:"FRI",5:"SAT",6:"SUN"}

# %%
solution(5,24)
# Out:
# 'TUE'

# %%
# 키값으로 벨류 가져오기
save[key]
# Out:
# 'ajsw'

# %%
save.get('MON')

# %%
save.items()
# Out:
# dict_items([(0, 'MON'), (1, 'TUE'), (2, 'WED'), (3, 'THU'), (4, 'FRI'), (5, 'SAT'), (6, 'SUN')])

# %%
for key, value in save.items():
    if 'MON' == value :
        print(key)
# Out:
# 0
