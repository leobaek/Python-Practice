# %%
from IPython.display import Image
Image('../image/Lv1. 가장 가까운 같은 글자.PNG', width=450)

# %%
# 프로그래머스 | 가장 가까운 같은 글자
def solution(s):

    alp_idx = {}
    answer = []
    
    for idx, alp in enumerate(s) :
        
        if alp not in alp_idx : 
            answer.append(-1)
        else :
        
    return answer

# %%
solution(b)
# Out:
# {'b': 0}
# {'b': 0, 'a': 1}
# {'b': 0, 'a': 1, 'n': 2}
# {'b': 0, 'a': 3, 'n': 2}
# {'b': 0, 'a': 3, 'n': 4}
# {'b': 0, 'a': 5, 'n': 4}
# [-1, -1, -1, 2, 2, 2]
