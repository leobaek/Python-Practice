# %%
from IPython.display import Image
Image('../image/Lv1. 직사각형 별찍기.PNG',width=450)

# %%
a, b = map(int, input().strip().split(' '))
for i in range(b) :
    print('*'*a)
# Out:
# 5 3
# *****
# *****
# *****

# %%
for i in range(1,7) :
    print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
