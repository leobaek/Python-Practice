# %%
from IPython.display import Image

Image('../image/Lv1. 나누어 떨어지는 숫자 배열.PNG', width=350)

# %%
def solution(arr, divisor):
    answer = []
    for i in arr:
        if i % divisor == 0 :
            answer.append(i)
    if len(answer) == 0:
        answer =[-1]
        
    return list(sorted(answer))

# %%
answer1 = [3,2,6,1,2]

# %%
answer1.sort()

# %%
answer1
# Out:
# [1, 2, 2, 3, 6]
