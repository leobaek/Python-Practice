# %%
from IPython.display import Image
Image('../image/Lv1. 문자열 내림차순으로 배치하기.PNG',width=450)

# %%
def solution(s):
    answer = ''
    answer= sorted(s,reverse=True)
    
    answer = "".join(answer)
            
    return answer

# %%
n = "Zbcdefg"
n = solution(n)

# %%
n
# Out:
# 'gfedcbZ'
