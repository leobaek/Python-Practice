# %%
from IPython.display import Image
Image('../image/Lv1.나머지가 1이 되는 수 찾기.png')

# %%
def solution(n):
    answer = 0
    for i in range(1,n+1):
        if n%i == 1 :
            answer+=i
            break
        
    return answer

# %%
solution(12)
# Out:
# 11
